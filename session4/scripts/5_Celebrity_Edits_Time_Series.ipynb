# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
df = pd.read_csv('../input/wikipedia_edits.csv.zip')

# %%
len(df)
# Out:
# 789343

# %%
df.head()
# Out:
#      title   parentid      revid             timestamp        user  \
# 0  50_Cent  858765697  858858564  2018-09-10T02:52:25Z  ProspectIV
# 1  50_Cent  858673799  858765697  2018-09-09T13:11:00Z  ProspectIV
# 2  50_Cent  858673121  858673799  2018-09-08T21:46:42Z  ProspectIV
# 3  50_Cent  858673016  858673121  2018-09-08T21:39:37Z  ProspectIV
# 4  50_Cent  858469414  858673016  2018-09-08T21:38:24Z  ProspectIV
#
#        userid    size recipient  year  rank        country    career  tied
# 0  33893830.0  132452   50 Cent  2006     8  United States  Musician     0
# 1  33893830.0  132476   50 Cent  2006     8  United States  Musician     0
# 2  33893830.0  132444   50 Cent  2006     8  United States  Musician     0
# 3  33893830.0  132345   50 Cent  2006     8  United States  Musician     0
# 4  33893830.0  132345   50 Cent  2006     8  United States  Musician     0

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#      title   parentid      revid                 timestamp        user  \
# 0  50_Cent  858765697  858858564 2018-09-10 02:52:25+00:00  ProspectIV
# 1  50_Cent  858673799  858765697 2018-09-09 13:11:00+00:00  ProspectIV
# 2  50_Cent  858673121  858673799 2018-09-08 21:46:42+00:00  ProspectIV
# 3  50_Cent  858673016  858673121 2018-09-08 21:39:37+00:00  ProspectIV
# 4  50_Cent  858469414  858673016 2018-09-08 21:38:24+00:00  ProspectIV
#
#        userid    size recipient  year  rank        country    career  tied
# 0  33893830.0  132452   50 Cent  2006     8  United States  Musician     0
# 1  33893830.0  132476   50 Cent  2006     8  United States  Musician     0
# 2  33893830.0  132444   50 Cent  2006     8  United States  Musician     0
# 3  33893830.0  132345   50 Cent  2006     8  United States  Musician     0
# 4  33893830.0  132345   50 Cent  2006     8  United States  Musician     0

# %%
df['date'] = df['timestamp'].dt.date

# %%
df.head()
# Out:
#      title   parentid      revid                 timestamp        user  \
# 0  50_Cent  858765697  858858564 2018-09-10 02:52:25+00:00  ProspectIV
# 1  50_Cent  858673799  858765697 2018-09-09 13:11:00+00:00  ProspectIV
# 2  50_Cent  858673121  858673799 2018-09-08 21:46:42+00:00  ProspectIV
# 3  50_Cent  858673016  858673121 2018-09-08 21:39:37+00:00  ProspectIV
# 4  50_Cent  858469414  858673016 2018-09-08 21:38:24+00:00  ProspectIV
#
#        userid    size recipient  year  rank        country    career  tied  \
# 0  33893830.0  132452   50 Cent  2006     8  United States  Musician     0
# 1  33893830.0  132476   50 Cent  2006     8  United States  Musician     0
# 2  33893830.0  132444   50 Cent  2006     8  United States  Musician     0
# 3  33893830.0  132345   50 Cent  2006     8  United States  Musician     0
# 4  33893830.0  132345   50 Cent  2006     8  United States  Musician     0
#
#          date
# 0  2018-09-10
# 1  2018-09-09
# 2  2018-09-08
# 3  2018-09-08
# 4  2018-09-08

# %%
df['date_year'] = df['timestamp'].dt.year

# %%
df.head()
# Out:
#      title   parentid      revid                 timestamp        user  \
# 0  50_Cent  858765697  858858564 2018-09-10 02:52:25+00:00  ProspectIV
# 1  50_Cent  858673799  858765697 2018-09-09 13:11:00+00:00  ProspectIV
# 2  50_Cent  858673121  858673799 2018-09-08 21:46:42+00:00  ProspectIV
# 3  50_Cent  858673016  858673121 2018-09-08 21:39:37+00:00  ProspectIV
# 4  50_Cent  858469414  858673016 2018-09-08 21:38:24+00:00  ProspectIV
#
#        userid    size recipient  year  rank        country    career  tied  \
# 0  33893830.0  132452   50 Cent  2006     8  United States  Musician     0
# 1  33893830.0  132476   50 Cent  2006     8  United States  Musician     0
# 2  33893830.0  132444   50 Cent  2006     8  United States  Musician     0
# 3  33893830.0  132345   50 Cent  2006     8  United States  Musician     0
# 4  33893830.0  132345   50 Cent  2006     8  United States  Musician     0
#
#          date  date_year
# 0  2018-09-10       2018
# 1  2018-09-09       2018
# 2  2018-09-08       2018
# 3  2018-09-08       2018
# 4  2018-09-08       2018

# %%
title = 'Manny_Pacquiao'
df_sub = df[df['title']==title]

# %%
len(df_sub)
# Out:
# 8917

# %%
df_sub.head()
# Out:
#                  title   parentid      revid                 timestamp  \
# 477505  Manny_Pacquiao  858923775  858924908 2018-09-10 15:07:25+00:00
# 477506  Manny_Pacquiao  858393401  858923775 2018-09-10 14:57:58+00:00
# 477507  Manny_Pacquiao  858392991  858393401 2018-09-06 21:20:17+00:00
# 477508  Manny_Pacquiao  858165549  858392991 2018-09-06 21:16:11+00:00
# 477509  Manny_Pacquiao  858165135  858165549 2018-09-05 14:23:28+00:00
#
#                  user      userid   size       recipient  year  rank  \
# 477505  MroWikipedian  34478357.0  96240  Manny Pacquiao  2015     2
# 477506  MroWikipedian  34478357.0  95925  Manny Pacquiao  2015     2
# 477507        Tbb 911   7097402.0  95879  Manny Pacquiao  2015     2
# 477508        Tbb 911   7097402.0  95954  Manny Pacquiao  2015     2
# 477509  PinoyBoxing11  15621670.0  95951  Manny Pacquiao  2015     2
#
#             country                 career  tied        date  date_year
# 477505  Philippines  Sportsperson (Boxing)     0  2018-09-10       2018
# 477506  Philippines  Sportsperson (Boxing)     0  2018-09-10       2018
# 477507  Philippines  Sportsperson (Boxing)     0  2018-09-06       2018
# 477508  Philippines  Sportsperson (Boxing)     0  2018-09-06       2018
# 477509  Philippines  Sportsperson (Boxing)     0  2018-09-05       2018

# %%
date_min = df_sub['date'].min()
date_max = df_sub['date'].max()

# %%
date_min, date_max
# Out:
# (datetime.date(2004, 8, 20), datetime.date(2018, 9, 10))

# %%
'Date range: {:%m/%d/%Y} to {:%m/%d/%Y}'.format(date_min, date_max)
# Out:
# 'Date range: 08/20/2004 to 09/10/2018'

# %%
df_daily = df_sub.groupby('date')['revid'].agg([len])

# %%
df_daily.head()
# Out:
#             len
# date
# 2004-08-20    5
# 2004-09-06    4
# 2004-09-12    1
# 2004-10-14    1
# 2004-10-22    1

# %%
len(df_daily)
# Out:
# 2023

# %%
x = df_daily.index

# %%
y = df_daily['len']

# %%
x, y
# Out:
# (Index([2004-08-20, 2004-09-06, 2004-09-12, 2004-10-14, 2004-10-22, 2004-11-17,
#         2004-11-25, 2004-12-02, 2004-12-04, 2004-12-12,
#         ...
#         2018-08-02, 2018-08-04, 2018-08-05, 2018-08-08, 2018-08-14, 2018-08-26,
#         2018-09-04, 2018-09-05, 2018-09-06, 2018-09-10],
#        dtype='object', name='date', length=2023), date
#  2004-08-20    5
#  2004-09-06    4
#  2004-09-12    1
#  2004-10-14    1
#  2004-10-22    1
#               ..
#  2018-08-26    1
#  2018-09-04    1
#  2018-09-05    4
#  2018-09-06    2
#  2018-09-10    2
#  Name: len, Length: 2023, dtype: int64)

# %%
plt.figure(figsize=(18, 6))
plt.plot(x, y, color='black')
plt.ylabel('No. of Wikipedia Edits')
plt.title('Daily Counts for %s' % title)
plt.minorticks_on()
# Out:
# /home/dan/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df_MP = df[df['title']=='Manny_Pacquiao']
df_FM = df[df['title']=='Floyd_Mayweather_jr.']

# %%
df_daily_MP = df_MP.groupby('date')['revid'].agg([len])
df_daily_FM = df_FM.groupby('date')['revid'].agg([len])

# %%
x_MP = df_daily_MP.index
x_FM = df_daily_FM.index
x_MP, x_FM
# Out:
# (Index([2004-08-20, 2004-09-06, 2004-09-12, 2004-10-14, 2004-10-22, 2004-11-17,
#         2004-11-25, 2004-12-02, 2004-12-04, 2004-12-12,
#         ...
#         2018-08-02, 2018-08-04, 2018-08-05, 2018-08-08, 2018-08-14, 2018-08-26,
#         2018-09-04, 2018-09-05, 2018-09-06, 2018-09-10],
#        dtype='object', name='date', length=2023),
#  Index([], dtype='object', name='date'))

# %%
y_MP = df_daily_MP['len']
y_FM = df_daily_FM['len']
y_MP, y_FM
# Out:
# (date
#  2004-08-20    5
#  2004-09-06    4
#  2004-09-12    1
#  2004-10-14    1
#  2004-10-22    1
#               ..
#  2018-08-26    1
#  2018-09-04    1
#  2018-09-05    4
#  2018-09-06    2
#  2018-09-10    2
#  Name: len, Length: 2023, dtype: int64, Series([], Name: len, dtype: float64))

# %%
plt.figure(figsize=(18, 6))
plt.plot(x_MP, y_MP, color='black')
plt.plot(x_FM, y_FM, color='red')
plt.ylabel('No. of Wikipedia Edits')
plt.title('Daily Counts for Manny Pacquiao (black) and Floyd Mayweather, Jr. (red)')
plt.minorticks_on()

# %%
df
# Out:
#           title   parentid      revid                 timestamp  \
# 0       50_Cent  858765697  858858564 2018-09-10 02:52:25+00:00
# 1       50_Cent  858673799  858765697 2018-09-09 13:11:00+00:00
# 2       50_Cent  858673121  858673799 2018-09-08 21:46:42+00:00
# 3       50_Cent  858673016  858673121 2018-09-08 21:39:37+00:00
# 4       50_Cent  858469414  858673016 2018-09-08 21:38:24+00:00
# ...         ...        ...        ...                       ...
# 789338       U2  383222001      74600 2002-02-25 15:43:11+00:00
# 789339       U2  383221849  383222001 2001-12-19 22:47:40+00:00
# 789340       U2     292008     292009 2001-12-12 08:28:48+00:00
# 789341       U2     292007     292008 2001-12-03 17:45:09+00:00
# 789342       U2          0     292007 2001-08-08 12:04:31+00:00
#
#                      user      userid    size recipient  year  rank  \
# 0              ProspectIV  33893830.0  132452   50 Cent  2006     8
# 1              ProspectIV  33893830.0  132476   50 Cent  2006     8
# 2              ProspectIV  33893830.0  132444   50 Cent  2006     8
# 3              ProspectIV  33893830.0  132345   50 Cent  2006     8
# 4              ProspectIV  33893830.0  132345   50 Cent  2006     8
# ...                   ...         ...     ...       ...   ...   ...
# 789338  Conversion script         0.0     406        U2  2011     4
# 789339     144.132.75.xxx         0.0     402        U2  2011     4
# 789340    202.161.127.xxx         0.0     654        U2  2011     4
# 789341    193.133.134.xxx         0.0     409        U2  2011     4
# 789342              Rrees  32609845.0     395        U2  2011     4
#
#                     country     career  tied        date  date_year
# 0             United States   Musician     0  2018-09-10       2018
# 1             United States   Musician     0  2018-09-09       2018
# 2             United States   Musician     0  2018-09-08       2018
# 3             United States   Musician     0  2018-09-08       2018
# 4             United States   Musician     0  2018-09-08       2018
# ...                     ...        ...   ...         ...        ...
# 789338  Republic of Ireland  Musicians     0  2002-02-25       2002
# 789339  Republic of Ireland  Musicians     0  2001-12-19       2001
# 789340  Republic of Ireland  Musicians     0  2001-12-12       2001
# 789341  Republic of Ireland  Musicians     0  2001-12-03       2001
# 789342  Republic of Ireland  Musicians     0  2001-08-08       2001
#
# [789343 rows x 15 columns]
